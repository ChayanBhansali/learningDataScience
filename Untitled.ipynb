# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('E:\python project\cleaned.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'avg_salary', 'company_txt',
#        'job_state', 'same_state', 'age', 'python_yn', 'R_yn', 'spark', 'aws',
#        'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# analyst           2220
# data engineer       17
# data scientist      14
# na                   1
# Name: job_simp, dtype: int64

# %%
df['seniority'] =  df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        1758
# senior     481
# jr          13
# Name: seniority, dtype: int64

# %%
df.job_state.value_counts()
# Out:
#  CA          626
#  TX          394
#  NY          345
#  IL          164
#  PA          114
#  AZ           97
#  NC           90
#  CO           88
#  NJ           86
#  WA           53
#  VA           48
#  OH           35
#  UT           33
#  FL           27
#  IN           23
#  DE           11
#  Arapahoe      8
#  GA            4
#  KS            3
#  SC            3
# Name: job_state, dtype: int64

# %%
# job description length

df['desc_len'] = df['Job Description'].apply(lambda x: len(x))

# %%
# Competitors count
df['Competitors_count'] = df['Competitors'].apply(lambda x: len(x.replace('and' , ',').split(',')) if x != '-1' else 0)

# %%
df.Competitors
# Out:
# 0                                                      -1
# 1                                                      -1
# 2                                                 GoDaddy
# 3                                                      -1
# 4                                              DraftKings
#                               ...
# 2247                                                   -1
# 2248                       Avnet, Ingram Micro, Tech Data
# 2249                                                   -1
# 2250                                                   -1
# 2251    Centura Health, HealthONE, Denver Health and H...
# Name: Competitors, Length: 2252, dtype: object

# %%
df.Competitors_count
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 2247    0
# 2248    3
# 2249    0
# 2250    0
# 2251    4
# Name: Competitors_count, Length: 2252, dtype: int64

# %%
#hourly wage to annual 

# df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
# df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
# dumb =df['Salary Estimate'].apply(lambda x : x if 'hour' in x else 0)
# df[dumb!=0][['Salary Estimate' , 'min_salary'] ]
# Out:
# Empty DataFrame
# Columns: [Salary Estimate, min_salary]
# Index: []

# %%
df.describe()
# Out:
#             Rating      Founded   min_salary   max_salary   avg_salary  \
# count  2252.000000  2252.000000  2252.000000  2252.000000  2252.000000
# mean      3.160080  1398.255329    54.266874    89.979130    72.123002
# std       1.665393   902.040151    19.575375    29.315605    23.600734
# min      -1.000000    -1.000000    24.000000    38.000000    33.500000
# 25%       3.100000    -1.000000    41.000000    70.000000    58.000000
# 50%       3.600000  1979.000000    50.000000    87.000000    69.000000
# 75%       4.000000  2002.000000    64.000000   104.000000    80.500000
# max       5.000000  2019.000000   113.000000   190.000000   150.000000
#
#         same_state          age    python_yn         R_yn        spark  \
# count  2252.000000  2252.000000  2252.000000  2252.000000  2252.000000
# mean      0.289076    31.272202     0.282860     0.005329     0.039520
# std       0.453434    45.267869     0.450489     0.072819     0.194873
# ...

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = [ 'avg_salary' ])
# Out:
# <AxesSubplot:>

# %%
df[['age' , 'avg_salary' , 'Rating' , 'desc_len' ]].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000   -0.075006  0.196955  0.255317
# avg_salary -0.075006    1.000000  0.004301 -0.033643
# Rating      0.196955    0.004301  1.000000 -0.018666
# desc_len    0.255317   -0.033643 -0.018666  1.000000

# %%
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df[['age' , 'avg_salary' , 'Rating' , 'desc_len' ]].corr(), cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len','Competitors_count']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'avg_salary', 'company_txt',
#        'job_state', 'same_state', 'age', 'python_yn', 'R_yn', 'spark', 'aws',
#        'excel', 'job_simp', 'seniority', 'desc_len', 'Competitors_count'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python_yn', 'R_yn',
       'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 253
# graph for Headquarters: total = 483
# graph for Size: total = 9
# graph for Type of ownership: total = 15
# graph for Industry: total = 89
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_txt: total = 1501
# graph for job_state: total = 20
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 4
# graph for seniority: total = 3

# %%
# instead of rotating , shifting parameters is way easier to read
# here I used inly top 20 outputs to be used in chart
for i in df_cat[['Location','Headquarters','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x= cat_num, y=cat_num.index)
#     chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'avg_salary', 'company_txt',
#        'job_state', 'same_state', 'age', 'python_yn', 'R_yn', 'spark', 'aws',
#        'excel', 'job_simp', 'seniority', 'desc_len', 'Competitors_count'],
#       dtype='object')

# %%
pd.pivot_table(df , index = 'job_simp' , values = 'avg_salary')
pd.pivot_table(df , index = 'job_simp' , values = 'avg_salary', aggfunc = 'count')
# Out:
#                 avg_salary
# job_simp
# analyst          72.174099
# data engineer    67.058824
# data scientist   70.785714
# na               63.500000

# %%
pd.pivot_table(df , index = ['job_simp' , 'seniority'] , values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          63.423077
#                na          71.577233
#                senior      74.609110
# data engineer  na          68.076923
#                senior      63.750000
# data scientist na          63.166667
#                senior      84.500000
# na             na          63.500000

# %%
pd.pivot_table(df , index = ['job_state' , 'job_simp'] , values = 'avg_salary').sort_values('job_state' , ascending = True)
# Out:
#                           avg_salary
# job_state job_simp
#  AZ       analyst          70.812500
#           data engineer    68.500000
#  Arapahoe analyst          72.571429
#           data engineer    70.000000
#  CA       analyst          88.362682
#           data engineer    76.125000
#           data scientist  119.166667
#  CO       analyst          73.619318
#  DE       analyst          59.727273
#  FL       analyst          51.851852
#  GA       analyst          44.000000
#  IL       analyst          78.109375
#           data engineer    77.500000
#           data scientist   95.250000
#  IN       analyst          47.500000
#  KS       analyst          51.500000
#  NC       analyst          68.112360
#           data engineer    68.000000
#  NJ       data scientist   66.500000
#           analyst          73.076471
#  NY       analyst          71.422515
#           data engineer    66.500000
#           data scientist   72.000000
#  OH       analyst          45.515152
# ...

# %%
pd.pivot_table(df , index = ['job_state' , 'job_simp'] , values = 'avg_salary', aggfunc = 'count').sort_values('job_state' , ascending = True)
# Out:
#                           avg_salary
# job_state job_simp
#  AZ       analyst                 96
#           data engineer            1
#  Arapahoe analyst                  7
#           data engineer            1
#  CA       analyst                619
#           data engineer            4
#           data scientist           3
#  CO       analyst                 88
#  DE       analyst                 11
#  FL       analyst                 27
#  GA       analyst                  4
#  IL       analyst                160
#           data engineer            2
#           data scientist           2
#  IN       analyst                 23
#  KS       analyst                  3
#  NC       analyst                 89
#           data engineer            1
#  NJ       data scientist           1
#           analyst                 85
#  NY       analyst                342
#           data engineer            1
#           data scientist           2
#  OH       analyst                 33
# ...

# %%
pd.pivot_table(df[df['job_simp'] == 'analyst'] , index = 'job_state' , values = 'avg_salary').sort_values('avg_salary' , ascending = False)
# Out:
#            avg_salary
# job_state
#  CA         88.362682
#  IL         78.109375
#  CO         73.619318
#  NJ         73.076471
#  Arapahoe   72.571429
#  NY         71.422515
#  AZ         70.812500
#  SC         68.333333
#  NC         68.112360
#  VA         65.187500
#  WA         64.754717
#  PA         61.491150
#  DE         59.727273
#  TX         58.808786
#  FL         51.851852
#  KS         51.500000
#  IN         47.500000
#  OH         45.515152
#  GA         44.000000
#  UT         37.672414
